# %% [markdown]
# # **Iris Dataset Analysis**
#
# Author: Anna Lozenko

# %%
# import all the necessary libraries

import numpy as np # https://numpy.org/
import matplotlib.pyplot as plt # https://matplotlib.org/3.5.3/api/_as_gen/matplotlib.pyplot.html
import sklearn as skl # https://scikit-learn.org/stable/
from sklearn import datasets 
import pandas as pd # https://pandas.pydata.org/

# %%
# load the Iris dataset from sklearn datasets library

iris = skl.datasets.load_iris(as_frame= True) # load the "data" from the dataset as a Pandas DataFrame (https://scikit-learn.org/1.4/modules/generated/sklearn.datasets.load_iris.html#sklearn.datasets.load_iris)

# %% [markdown]
# # Explore the Iris Dataset

# %%
print(iris)
# Out:
# {'data':      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# ...

# %% [markdown]
# When we load the Iris dataset, it is returned as a dictionary-like object, which stores information in key–value pairs. The structure includes:
#
# - **data**: a NumPy array containing the numeric feature values for each sample (sepal length, sepal width, petal length, petal width).
#
# - **target**: an array of numeric labels (0, 1, 2) representing the target classes (species of iris).
#
# - **frame**: it is None by default. Since *as_frame = True* is set, the dataset has been returned as a DataFrame with data and target.
#
# - **target_names**: an array with the names of the target classes (setosa, versicolor, virginica).
#
# - **DESCR**: a string with the detailed description of the dataset.
#
# - **feature_names**: a list of feature names (sepal length, sepal width, petal length, petal width) describing the columns of "data".
#
# - **filename**: dataset path.
#
# - **data_module**: dataset origin module in the sklearn.datasets.

# %%
# show "data" as a Pandas DataFrame
print(iris["data"])
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
# explore the shape of "data"
print(iris["data"].shape)
# Out:
# (150, 4)

# %% [markdown]
# We can see that "data" contains 150 rows and 4 columns.

# %%
# print the head of the "data"
print(iris["data"].head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
# print the tail of the "data"
print(iris["data"].tail())
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8

# %% [markdown]
# We can see that "data" contains 150 rows (corresponding to 150 samples), and 4 columns (corresponding to 4 features).
#
# 1. sepal length (cm)
#
# 2. sepal width (cm)
#
# 3. petal length (cm)
#
# 4. petal width (cm)

# %% [markdown]
# # Features Analysis

# %%
# Indexing columns in Pandas DataFrame (https://pandas.pydata.org/docs/user_guide/indexing.html)
sl = iris.data.iloc[:, 0] # sepal length
sw = iris.data.iloc[:, 1] # sepal width
pl = iris.data.iloc[:, 2] # petal length
pw = iris.data.iloc[:, 3] # petal width

# %%
# create a function that performs the features analysis and returns the results
def feature_analysis (x):
    mean = np.mean(x) # mean
    median = np.median(x) # median
    std = np.std(x) # standard deviation
    min = np.min(x) # minimum value
    max = np.max(x) # maximum value 
    return(f"Mean: {mean:.2f}.\nMedian: {median:.2f}.\nStandard deviation: {std:.2f}.\nMinimum value: {min:.2f}.\nMaximum value: {max:.2f}.")

# %% [markdown]
# Store and print out the results of feature analysis:

# %%
sl_analysis = feature_analysis(sl) # analysis of sepal length
print(sl_analysis)
# Out:
# Mean: 5.84.
# Median: 5.80.
# Standard deviation: 0.83.
# Minimum value: 4.30.
# Maximum value: 7.90.

# %%
sw_analysis = feature_analysis(sw) # analysis of sepal width
print(sw_analysis)
# Out:
# Mean: 3.06.
# Median: 3.00.
# Standard deviation: 0.43.
# Minimum value: 2.00.
# Maximum value: 4.40.

# %%
pl_analysis = feature_analysis(pl) # analysis of petal length
print(pl_analysis)
# Out:
# Mean: 3.76.
# Median: 4.35.
# Standard deviation: 1.76.
# Minimum value: 1.00.
# Maximum value: 6.90.

# %%
pw_analysis = feature_analysis(pw) # analysis of petal width
print(pw_analysis)
# Out:
# Mean: 1.20.
# Median: 1.30.
# Standard deviation: 0.76.
# Minimum value: 0.10.
# Maximum value: 2.50.

# %% [markdown]
# Summarize the analysis of all the features in a DataFrame:

# %%
# creation of a DataFrame with features summary  (https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html)
features_summary= pd.DataFrame({
    "Mean" : iris["data"].mean(),
    "Median" : iris["data"].median(),
    "Standard Deviation" : iris["data"].std(),
    "Minimum" : iris["data"].min(),
    "Maximum" : iris["data"].max()
})

# %%
# print out the DataFrame
print(features_summary)
# Out:
#                        Mean  Median  Standard Deviation  Minimum  Maximum
# sepal length (cm)  5.843333    5.80            0.828066      4.3      7.9
# sepal width (cm)   3.057333    3.00            0.435866      2.0      4.4
# petal length (cm)  3.758000    4.35            1.765298      1.0      6.9
# petal width (cm)   1.199333    1.30            0.762238      0.1      2.5

# %% [markdown]
# Create a text file to store the output of iris features analysis:

# %%
# create a text file with features analysis data
with open ("Iris Dataset Variables Analysis.txt", "w") as f:
    f.write(f"IRIS SEPAL LENGTH ANALYSIS:\n{sl_analysis}\n\n\n")
    f.write(f"IRIS SEPAL WIDTH ANALYSIS:\n{sw_analysis}\n\n\n")
    f.write(f"IRIS PETAL LENGTH ANALYSIS:\n{pl_analysis}\n\n\n")
    f.write(f"IRIS PETAL WIDTH ANALYSIS:\n{pw_analysis}\n\n\n")
    f.write(f"FEATURES SUMMARY:\n{features_summary}")

# %% [markdown]
# # Histograms

# %% [markdown]
# For the creation of histogram plots Matplotlib will be used.
# Matplotlib is a very useful Python library that can be used to create different types of plots and visualize data.
# https://matplotlib.org/

# %% [markdown]
# A histogram is a plot showing the frequency distribution (on the y-axes) of a variable (on the x-axis).
# It shows the distribution of the variable values within a given interval.
#
# https://www.w3schools.com/python/matplotlib_histograms.asp

# %%
# define a function that create histogram plots
def histogram_creator (x, title = "", xlab = "", ylab = "",  color = "blue", edgecolor = "black", grid = False, save = False, **kwargs): # define the arguments of the function
    plt.xlabel(f"{xlab}") # define the x axes label
    plt.ylabel(f"{ylab}") # define the y axes label
    title_font= {"family": "sans-serif", "color" : "black", "size" : 16, "weight" : "bold"} # create a different font for the title of the plot (https://how.dev/answers/how-to-set-font-properties-for-title-and-labels-in-matplotlib, https://matplotlib.org/stable/users/explain/text/text_props.html)
    plt.title (f"{title}", fontdict= title_font) # define the title of the plot
    plt.hist(x, edgecolor = edgecolor, color = color, **kwargs) # create the plot
    if grid == True: # define how the grid will be visualized by default
        plt.grid(alpha = 0.2) # grid transparency set on 80%
    if save == True: # define how the image of the plot will be saved by default
        plt.savefig(f"{title}.png")
    plt.show()

# %%
# create the histogram plot of Sepal Length (cm)
histogram_creator(sl, title = "Sepal Length Histogram", xlab = "Sepal Length (cm)", ylab= "Frequency", grid = True);

# %% [markdown]
# The histogram plot of sepal length shows that most flowers have a sepal length around 5.5 - 6.0 cm, while few have very short and very long sepals.
# The distribution range is broad, but we can see 3 peaks. If these 3 peaks are related to different species of *Iris* flowers, this feature may be helpful in discriminating them.

# %%
# create the histogram plot of Sepal Width (cm)
histogram_creator(sw, title = "Sepal Width Histogram", xlab = "Sepal Width (cm)", ylab = "Frequency", color = "green", grid = True)

# %% [markdown]
# The histogram plot of sepal width shows that many flowers have a sepal width between 2.5 and 3.3 cm, while few have very narrow or broad sepals.

# %%
# create the histogram plot of Petal Length (cm)
histogram_creator(pl, title = "Petal Length Histogram", xlab = "Petal Length (cm)", ylab = "Frequency", color = "red", grid = True)

# %% [markdown]
# The histogram plot of petal length shows 2 peaks, with a bimodal distribution type.
# There is a great separation between short and long petals, which can help classify flowers if these values are related to the *Iris* species.

# %%
# create the histogram plot of Petal Width (cm)
histogram_creator(pw, title = "Petal Width Histogram", xlab = "Petal Width (cm)", ylab = "Frequency", color = "orange", grid = True)

# %% [markdown]
# The histogram plot of petal width shows a bimodal or trimodal distribution.
# This feature can be informative and can be used to classify *Iris* flowers if it's related to the species.

# %% [markdown]
# # Scatterplots

# %% [markdown]
# A scatterplot displays individual data points on a two-dimensional plane. Each point represents the values of two variables, with one plotted on the x-axis and the other on the y-axis.
# Scatterplots help visualize relationships, correlations, and patterns between variables.
#
# https://en.wikipedia.org/wiki/Scatter_plot

# %%
# define a function that creates scatterplots
def scatterplot_creator (x, y, xlab = "", ylab = "", c = "red", title = "", grid = False, save = False, fitline = False, **kwargs): # define the arguments of the function
    plt.scatter(x, y , c = c, **kwargs) # create the plot (https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html)
    plt.xlabel(f"{xlab}") # define the x axes label
    plt.ylabel(f"{ylab}") # define the y axes label
    title_font= {"family": "sans-serif", "color" : "black", "size" : 16, "weight" : "bold"} # use a custom font for the title
    plt.title(f"{title}", fontdict= title_font) # define the title of the plot
    if grid == True: # define how grid will appear by default
        plt.grid(alpha = 0.2) # grid transparency set on 80%
    if save == True: # define how images of plots will be saved by default
        plt.savefig(f"{title}.png")
    if fitline == True: # calculate the parameters of the regression line to examine the linear relationship between variables (https://numpy.org/doc/stable/reference/generated/numpy.polyfit.html, https://www.geeksforgeeks.org/line-of-best-fit/ )
        m, c = np.polyfit(x, y, deg = 1) # slope (m), intercept (c)
        plt.plot(x, m*x + c, color = "red") # plot of the regression line
        plt.legend (["Data", "Line of Best Fit"])
    plt.show()

# %% [markdown]
# It is very useful to represent the species of *Iris* flowers by different colors, to understand how the features appear in different species and if they can be used to discriminate the different species of *Iris* flowers.

# %%
# print the unique values in Iris "target" and count them (https://numpy.org/doc/stable/reference/generated/numpy.unique.html)
np.unique(iris["target"], return_counts= True)
# Out:
# (array([0, 1, 2]), array([50, 50, 50]))

# %% [markdown]
# The 3 species of *Iris* are defined by 3 different target numbers (0, 1, 2), counting 50 samples each.

# %%
# define the species based on "target" value
species = iris["target"]

# %%
# create a scatterplot of Sepal Length vs Sepal Width, with the three species of iris flowers represented by different colors
scatterplot_creator (sl, sw, xlab= "Sepal Length (cm)", ylab= "Sepal Width (cm)", title= "Sepal Length vs Sepal Width", c = species)

# %%
# create a scatterplot of Sepal Length vs Petal Length, with the three species of iris flowers represented by different colors
scatterplot_creator(sl, pl, xlab= "Sepal Length (cm)", ylab= "Petal Length (cm)", title= "Sepal Length vs Petal Length", c= species)

# %%
# create a scatterplot of Sepal Length vs Petal Width, with the three species of iris flowers represented by different colors
scatterplot_creator(sl, pw, xlab= "Sepal Length (cm)", ylab= "Petal Width (cm)", title= "Sepal Length vs Petal Width", c= species)

# %%
# create a scatterplot of Petal Length vs Sepal Width, with the three species of iris flowers represented by different colors
scatterplot_creator(pl, sw, xlab= "Petal Length (cm)", ylab= "Sepal Width (cm)", title= "Petal Length vs Sepal Width", c= species)

# %%
# create a scatterplot of Petal Width vs Sepal Width, with the three species of iris flowers represented by different colors
scatterplot_creator(pw, sw, xlab= "Petal Width", ylab= "Sepal Width (cm)", title= "Petal Width vs Sepal Width", c= species)

# %%
# create a scatterplot o Petal Length vs Petal Width, with the three species of iris flowers represented by different colors
scatterplot_creator(pl, pw, xlab= "Petal Length (cm)", ylab= "Petal Width (cm)", title= "Petal Length vs Petal Width", c= species)

# %% [markdown]
# # Any other approprate analysis

# %% [markdown]
# ## Boxplots

# %% [markdown]
# A boxplot is a useful tool that graphically demonstrates how data is distributed using quartiles. It allows us to visualize skewness, detect outliers, assess central tendency (such as the median), and compare different datasets more easily.
# A boxplot shows important information, such as:
#
# - Minimum
#
# - First quartile (Q1), 25th percentile
#
# - Median (Q2), the middle value of a dataset
#
# - Third quartile (Q3), 75th percentile
#
# - Maximum
#
# - The Interquartile range (IQR), which is Q3 - Q1
#
# - Outliers
#
# Each quartile corresponds to 25% of data. Whiskers are useful for visualizing the minimum and maximum values within a certain range, while any ouliers (extremely large or small values) are shown as individual data points outside the whiskers.
# https://en.wikipedia.org/wiki/Box_plot
# https://www.khanacademy.org/math/statistics-probability/summarizing-quantitative-data/box-whisker-plots/a/box-plot-review
#
#
# As we have seen, there are three classes of *Iris* flowers: *setosa*, *versicolor* and *virginica*, identified as 0, 1, and 2, respectively.

# %%
# define the species based on target number
setosa = iris["data"][iris["target"] == 0]
versicolor = iris["data"][iris["target"] == 1]
virginica = iris["data"][iris["target"] == 2]

# %%
# define a function that creates boxplots
def boxplots_creator (x, title = "", xlab = "", ylab= "", ticklabs = "", grid = False, save = False, **kwargs):
    fig, ax = plt.subplots() # option to create multiple plots on the same figure (https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html)
    ax.boxplot(x, patch_artist= True) # create boxplot filled with color
    title_font= {"family": "sans-serif", "color" : "black", "size" : 16, "weight" : "bold"} # create a custom font for the title
    ax.set_ylabel (f"{ylab}", fontsize = 12) # set the y axes label
    ax.set_xlabel(f"{xlab}", fontsize = 12) # set the x axes label
    ax.set_xticklabels(ticklabs) # create labels for each tick mark on the x axes
    ax.set_title (f"{title}", fontdict = title_font) # set a title 
    if grid == True: # define how grid will be visualized by deafult
        ax.grid(axis = "y", alpha = 0.5, linestyle = "--") # grid transparency set on 50%, grid made with dashed line, located on the y axes
    if save == True:  # define how the image will be savedby default
        plt.savefig(f"{title}.png")
    plt.show()

# %% [markdown]
# Exploring petal lengths of the different species:

# %%
# define petal lengths of the different species
setosa_pl = setosa["petal length (cm)"]
versicolor_pl = versicolor["petal length (cm)"]
virginica_pl = virginica ["petal length (cm)"]

# %%
# create the boxplot for Iris setosa petal length
boxplots_creator(setosa_pl, title= "Iris Setosa Petal Length", xlab= "Iris setosa", ylab="Petal Length (cm)", grid = True)

# %%
# create the boxplot for Iris versicolor petal length
boxplots_creator(versicolor_pl, title= "Iris Versicolor Petal Length", xlab= "Iris versicolor", ylab="Petal Length (cm)", grid = True )

# %%
# create the boxplot for Iris virginica petal length
boxplots_creator(virginica_pl, title= "Iris Virginica Petal Length", xlab= "Iris virginica", ylab="Petal Length (cm)", grid = True )

# %%
# visualize all the boxplots in one figure
boxplots_creator([setosa_pl, versicolor_pl, virginica_pl], ticklabs= ["setosa", "versicolor", "virginica"], xlab= "Species", ylab= "Petal Length (cm)", title = "Petal Lengths of All Species", grid = True)

# %% [markdown]
# The boxplots for petal length across the 3 *Iris* species show a strong visual separation.
# *Iris setosa* shows the the shortest petal length with little variation, while *versicolor* and *virginica* have longer and more varied petal lengths.
# The petal length appears to be a highly informative feature for species classification, as the 3 species data almost do not overlap, especially with *setosa* boxplot being very far apart from the others.

# %% [markdown]
# Exploring petal width of the different species:

# %%
# define the petal width of the different species
setosa_pw = setosa["petal width (cm)"]
versicolor_pw = versicolor["petal width (cm)"]
virginica_pw = virginica["petal width (cm)"]

# %%
# create the boxplot for Iris setosa petal width
boxplots_creator(setosa_pw, title= "Iris Setosa Petal Width", xlab= "Iris setosa", ylab="Petal Width (cm)", grid = True )

# %%
# create the boxplot for Iris versicolor petal width
boxplots_creator(versicolor_pw, title= "Iris Versicolor Petal Width", xlab= "Iris versicolor", ylab="Petal Width (cm)", grid = True )

# %%
# create the boxplot for Iris virginica petal width
boxplots_creator(virginica_pw, title= "Iris Virginica Petal Width", xlab= "Iris virginica", ylab="Petal Width (cm)", grid = True )

# %%
# visualize all the boxplots in one figure
boxplots_creator([setosa_pw, versicolor_pw, virginica_pw], ticklabs= ["setosa", "versicolor", "virginica"], xlab= "Species", ylab= "Petal Width (cm)", title = "Petal Width of All Species", grid = True)

# %% [markdown]
# The boxplot for petal width shows a good separation for all the species, especially for the *Iris setosa* species.
# This feature is very informative and can be used to discriminate the different species of *Iris* flowers.
# The data for all the species is skewed, especially that of *Iris setosa*.
# *Iris setosa* shows less variability and significantly narrower petals with respect to the other 2 species.
# *Iris virginica* shows the widest petals.

# %% [markdown]
# Exploring sepal length of the different species:

# %%
# define the sepal length of the different species
setosa_sl = setosa["sepal length (cm)"]
versicolor_sl = versicolor["sepal length (cm)"]
virginica_sl = virginica["sepal length (cm)"]

# %%
# create the boxplot for Iris setosa sepal length
boxplots_creator(setosa_sl, title= "Iris Setosa Sepal Length", xlab= "Iris setosa", ylab="Sepal Length (cm)", grid = True )

# %%
# create the boxplot for Iris versicolor sepal length
boxplots_creator(versicolor_sl, title= "Iris Versicolor Sepal Length", xlab= "Iris versicolr", ylab="Sepal Length (cm)", grid = True )

# %%
# create the boxplot for Iris virginica sepal length
boxplots_creator(virginica_sl, title= "Iris Virginica Sepal Length", xlab= "Iris virginica", ylab="Sepal Length (cm)", grid = True )

# %%
# visualize all the boxplots in one figure
boxplots_creator([setosa_sl, versicolor_sl, virginica_sl], ticklabs= ["setosa", "versicolor", "virginica"], xlab= "Species", ylab= "Sepal Length (cm)", title = "Sepal Lengths of All Species", grid = True)

# %% [markdown]
# The boxplot of sepal length shows a good separation especially for *Iris setosa*, while the other 2 species data widely overlaps.
# Dta is slightly skewed for all species.
# This feature is not really useful for species discrimination, except for the discrimination of *Iris setosa*.
# *Iris setosa* has the shortest sepals, while *virginica* has the longest.

# %% [markdown]
# Exploring sepal width of the different species:

# %%
# define the sepal width of the different species
setosa_sw = setosa["sepal width (cm)"]
versicolor_sw = versicolor["sepal width (cm)"]
virginica_sw = virginica["sepal width (cm)"]

# %%
# create the boxplot for Iris setosa sepal width
boxplots_creator(setosa_sw, title= "Iris Setosa Sepal Width", xlab= "Iris setosa", ylab="Sepal Width (cm)", grid = True )

# %%
# create the boxplot for Iris versicolor sepal width
boxplots_creator(versicolor_sw, title= "Iris Versicolor Sepal Width", xlab= "Iris versicolor", ylab="Sepal Width (cm)", grid = True )

# %%
# create the boxplot for Iris virginica sepal width
boxplots_creator(virginica_sw, title= "Iris Virginica Sepal Width", xlab= "Iris virginica", ylab="Sepal Width (cm)", grid = True )

# %%
# visualize all the boxplots in one figure
boxplots_creator([setosa_sw, versicolor_sw, virginica_sw], ticklabs= ["setosa", "versicolor", "virginica"], xlab= "Species", ylab= "Sepal Width (cm)", title = "Sepal Width of All Species", grid = True)

# %% [markdown]
# The boxplot of sepal width shows a lot of variability and slight data skewness for all the species.
# Data of *Iris virginica* and *versciolor* overlaps, making this feature not useful for their discrimination. *Iris setosa* can be distinguished more easily and presents wider sepals with respect to the other species.
